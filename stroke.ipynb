# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('GBD_2023.csv')
data.head()
# Out:
#    population_group_id population_group_name  measure_id measure_name  \
# 0                    1        All Population           1       Deaths
# 1                    1        All Population           1       Deaths
# 2                    1        All Population           1       Deaths
# 3                    1        All Population           1       Deaths
# 4                    1        All Population           1       Deaths
#
#    location_id location_name  sex_id sex_name  age_id     age_name  cause_id  \
# 0           79       Finland       1     Male      10  25-29 years       495
# 1           79       Finland       2   Female      10  25-29 years       495
# 2           79       Finland       1     Male      11  30-34 years       495
# 3           79       Finland       2   Female      11  30-34 years       495
# 4           79       Finland       1     Male      12  35-39 years       495
#
#         cause_name  metric_id metric_name  year       val     upper     lower
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 97104 entries, 0 to 97103
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   population_group_id    97104 non-null  int64
#  1   population_group_name  97104 non-null  str
#  2   measure_id             97104 non-null  int64
#  3   measure_name           97104 non-null  str
#  4   location_id            97104 non-null  int64
#  5   location_name          97104 non-null  str
#  6   sex_id                 97104 non-null  int64
#  7   sex_name               97104 non-null  str
#  8   age_id                 97104 non-null  int64
#  9   age_name               97104 non-null  str
#  10  cause_id               97104 non-null  int64
#  11  cause_name             97104 non-null  str
#  12  metric_id              97104 non-null  int64
#  13  metric_name            97104 non-null  str
#  14  year                   97104 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# population_group_id      0
# population_group_name    0
# measure_id               0
# measure_name             0
# location_id              0
# location_name            0
# sex_id                   0
# sex_name                 0
# age_id                   0
# age_name                 0
# cause_id                 0
# cause_name               0
# metric_id                0
# metric_name              0
# year                     0
# val                      0
# upper                    0
# lower                    0
# dtype: int64

# %%
data.isna().any()
# Out:
# population_group_id      False
# population_group_name    False
# measure_id               False
# measure_name             False
# location_id              False
# location_name            False
# sex_id                   False
# sex_name                 False
# age_id                   False
# age_name                 False
# cause_id                 False
# cause_name               False
# metric_id                False
# metric_name              False
# year                     False
# val                      False
# upper                    False
# lower                    False
# dtype: bool
